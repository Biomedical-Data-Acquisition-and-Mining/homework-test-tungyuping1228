# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('G:/My Drive/人生/大學/亞大/10902/生醫資料探勘/diabetes.csv');

print("\n \t The data frame has {0[0]} rows and {0[1]} columns. \n".format(data.shape))
data.info()

data.head()
# Out:
#  	 The data frame has 768 rows and 13 columns.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Gender                    768 non-null    object
#  2   Glucose                   768 non-null    int64
#  3   BloodPressure             768 non-null    int64
#  4   SkinThickness             768 non-null    int64
#  5   Insulin                   768 non-null    int64
#  6   BMI                       768 non-null    float64
#  7   DiabetesPedigreeFunction  768 non-null    float64
#  8   Age                       768 non-null    int64
#  9   Outcome                   768 non-null    int64
#  10  CalorieIntake             753 non-null    float64
#  11  Exercise                  768 non-null    object
#  12  SleepDuration             768 non-null    int64
# ...

# %%
data.drop(data.columns[[-1, 0]], axis=1, inplace=True)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Gender                    768 non-null    object
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
#  9   CalorieIntake             753 non-null    float64
#  10  Exercise                  768 non-null    object
# dtypes: float64(3), int64(6), object(2)
# memory usage: 66.1+ KB

# %%
data.head()
# Out:
#   Gender  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      M      148             72             35        0  33.6
# 1      F       85             66             29        0  26.6
# 2      M      183             64              0        0  23.3
# 3      F       89             66             23       94  28.1
# 4      M      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  CalorieIntake Exercise
# 0                     0.627   50        1         2508.3       No
# 1                     0.351   31        0         2760.0  Evening
# 2                     0.672   32        1         6480.0  Morning
# 3                     0.167   21        0            NaN  Evening
# 4                     2.288   33        1         1970.0       No

# %%
BMI_all = list(data.shape)[0]
BMI_categories = list(data['BMI'].value_counts())

# %%
BMI_all = list(data.shape)[0]
BMI_categories = list(data['BMI'].value_counts())

print("\n \t The data has {}BMI, {} malignant and {} benign.".format(BMI_all, 
                                                                                BMI_categories[0], 
                                                                                 BMI_categories[1]))
# Out:
#  	 The data has 768BMI, 13 malignant and 12 benign.

# %%
features_mean= list(data.columns[1:11])

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data[features_mean].corr(), annot=True, square=True, cmap='coolwarm')
plt.show()
